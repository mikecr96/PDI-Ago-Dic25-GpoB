# %%
# %pip install opencv-python
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2 as cv

# %%
# Leer imagen

imagen = cv.imread("perrito.jpg")
# Out:
# [ WARN:0@0.031] global loadsave.cpp:275 findDecoder imread_('perrito.jpg'): can't open/read file: check file path/integrity

# %%
type(imagen)
# Out:
# NoneType

# %%
imagen.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 imagen.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
logo_diablos = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI - Ago-dic22/Clase 2 - Imágenes/images/diablos_rojos-logo.png")

# %%
type(logo_diablos)
# Out:
# numpy.ndarray

# %%
logo_diablos.shape
# Out:
# (143, 300, 3)

# %%
# %pip install matplotlib
# Out:
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
# from matplotlib import pyplot as plt

# %%
# Mostrar imagen CON PYPLOT (MATPLOTLIB)

plt.imshow(logo_diablos)
plt.show()

# %%
# OpenCV lee imágenes en BGR
# Matplotlib muestra imagenes en RGB
# BGR ->
# RGB

# %%
canal_B = logo_diablos[:, :, 0]
canal_G = logo_diablos[:, :, 1]
canal_R = logo_diablos[:, :, 2]

# %%
type(canal_B)
# Out:
# numpy.ndarray

# %%
canal_B.shape
# Out:
# (143, 300)

# %%
logo_diablos.shape
# Out:
# (143, 300, 3)

# %%
canal_R[100, 100]
# Out:
# np.uint8(227)

# %%
"""
uint8
0-255
256 combinaciones
0 -> negro (ausencia de color)
[1-254] -> escala de gris
[1-127] : son grises oscuros
[128-254] : son grises claros
255 -> blanco (saturación)
"""

# %%
plt.imshow(canal_R, cmap="gray")
plt.show()

# %%
# 18, 20
canal_R[17, 19]
# Out:
# np.uint8(0)

# %%
# 90, 260
canal_R[89, 259]
# Out:
# np.uint8(227)

# %%
plt.imshow(canal_G, cmap="gray")
plt.show()

# %%
plt.imshow(canal_B, cmap="gray")
plt.show()

# %%
plt.imshow(logo_diablos, cmap="gray")
plt.show()

# %%
"""
OpenCV lee la imagen en    BGR
PyPlot espera la imagen en RGB
"""

plt.imshow(logo_diablos[:, :, ::-1])
plt.show()

# %%
# Mostrar solo el color rojo
# apagamos canal G y B
canal_B[:, :] = 0
canal_G[:, :] = 0

# %%
logo_diablos_SOLOROJO = cv.merge((canal_R, canal_G, canal_B))

# %%
logo_diablos_SOLOROJO.shape
# Out:
# (143, 300, 3)

# %%
plt.imshow(logo_diablos_SOLOROJO)
plt.show()
