# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Grayscale

# %%
lena_gray = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic25/Grupo B/images/lena.jpg", 0)
lena_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(lena_gray, cmap="gray")
plt.show()

# %%
histograma = cv.calcHist([lena_gray], (0, ), None, [256], [0, 256])

# %%
histograma.shape
# Out:
# (256, 1)

# %%
plt.imshow(histograma)
plt.show()

# %%
lena_gray.size
# Out:
# 262144

# %%
plt.plot(histograma)
plt.title("Histograma de Lena grayscale")
plt.show()

# %% [markdown]
# ## A color

# %%
lena_bgr = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic25/Grupo B/images/lena.jpg")
lena_bgr.shape
# Out:
# (512, 512, 3)

# %%
# histograma_b = cv.calcHist([lena_bgr], (0,), None, [256], [0, 256])
# histograma_g = cv.calcHist([lena_bgr], (1,), None, [256], [0, 256])
# histograma_r = cv.calcHist([lena_bgr], (2,), None, [256], [0, 256])

# plt.plot(histograma_b)
# plt.title("Histograma del canal B")
# plt.show()

# plt.plot(histograma_g)
# plt.title("Histograma del canal G")
# plt.show()

# plt.plot(histograma_r)
# plt.title("Histograma del canal R")
# plt.show()

# %% [markdown]
# ---

# %%
colores = ["b", "g", "r"]

for conteo, color in enumerate(colores):
    print("Conteo:", conteo, "Color:", color)
# Out:
# Conteo: 0 Color: b
# Conteo: 1 Color: g
# Conteo: 2 Color: r

# %%
nombre = "Miguel"
apellido = "Camargo"
universidad = "UP"

print("Hola amigo {} {} de la Universidad {}".format(nombre, apellido, universidad))
# Out:
# Hola amigo Miguel Camargo de la Universidad UP

# %%
print(f"Hola amigo {nombre + " Angel"} {apellido} de la Universidad {universidad}") # f-string
# Out:
# Hola amigo Miguel Angel Camargo de la Universidad UP

# %% [markdown]
# ---

# %%
colores = ["b", "g", "r"]

for i in range(3):
    tmp = cv.calcHist([lena_bgr], (i,), None, [256], [0, 256])
    plt.plot(tmp, colores[i])
plt.show()

# %%
colores = ["b", "g", "r"]

for conteo, color in enumerate(colores):
    tmp = cv.calcHist([lena_bgr], (conteo,), None, [256], [0, 256])
    plt.plot(tmp, color)
plt.show()
