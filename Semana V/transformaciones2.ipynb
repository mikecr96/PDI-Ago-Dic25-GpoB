# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
lena_bgr = cv.imread('/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic25/Grupo B/images/lena.jpg')

# %%
lena_bgr.shape
# Out:
# (512, 512, 3)

# %%
# CARGAR la imagen en Grayscale
lena_gray = cv.imread('/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic25/Grupo B/images/lena.jpg', 0) # La bandera 0, carga en Grayscale
lena_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(lena_gray, cmap='gray')
plt.show()

# %% [markdown]
# ---
# ## Gamma

# %%
# Pythonic
2 ** 10
# Out:
# 1024

# %%
# NumPy
np.power(2, 10)
# Out:
# np.int64(1024)

# %%
mat10x10 = np.random.randint(11, size=(10, 10))

# %%
mat10x10
# Out:
# array([[ 4,  6,  6,  2,  0,  1,  3,  1,  7,  7],
#        [ 8,  2,  4, 10,  7,  1,  6,  6,  0, 10],
#        [ 0,  5,  7,  9,  5,  2,  5,  3,  6,  8],
#        [ 1,  6,  1,  2,  1, 10,  2,  2,  1,  1],
#        [ 4, 10, 10,  2,  2,  4,  1,  8,  9,  9],
#        [ 4,  8,  4,  5,  7,  4,  5,  4,  3,  3],
#        [ 2,  1,  1,  8,  5, 10,  3,  3,  5,  4],
#        [ 8, 10,  3,  4,  1,  5,  2, 10,  3,  0],
#        [ 5,  4,  8,  9,  3,  6,  5,  4,  1,  3],
#        [ 8,  7,  9,  0,  3,  6,  0, 10,  3,  9]])

# %%
np.power(mat10x10, 2)
# Out:
# array([[ 16,  36,  36,   4,   0,   1,   9,   1,  49,  49],
#        [ 64,   4,  16, 100,  49,   1,  36,  36,   0, 100],
#        [  0,  25,  49,  81,  25,   4,  25,   9,  36,  64],
#        [  1,  36,   1,   4,   1, 100,   4,   4,   1,   1],
#        [ 16, 100, 100,   4,   4,  16,   1,  64,  81,  81],
#        [ 16,  64,  16,  25,  49,  16,  25,  16,   9,   9],
#        [  4,   1,   1,  64,  25, 100,   9,   9,  25,  16],
#        [ 64, 100,   9,  16,   1,  25,   4, 100,   9,   0],
#        [ 25,  16,  64,  81,   9,  36,  25,  16,   1,   9],
#        [ 64,  49,  81,   0,   9,  36,   0, 100,   9,  81]])

# %%
25 ** 2
# Out:
# 625

# %%
lena_power = np.power(lena_gray, 2)

plt.imshow(lena_power, cmap='gray')
plt.show()

# %%
lena_power.dtype
# Out:
# dtype('uint8')

# %%
lena_gray[299, 19]
# Out:
# np.uint8(71)

# %%
71 ** 2
# Out:
# 5041

# %%
lena_power[299, 19]
# Out:
# np.uint8(177)

# %%
5041 % 256
# Out:
# 177

# %%
10 % 3
# Out:
# 1

# %%
plt.imshow(np.power(lena_gray, 2.5), cmap='gray')
plt.show()
