# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
ardilla_gray = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic25/Grupo B/images/squirrel_cls.jpg", 0)

# %%
ardilla_gray.shape
# Out:
# (426, 535)

# %%
hist_gray = cv.calcHist([ardilla_gray], [0], None, [256], [0, 256])
plt.plot(hist_gray)
plt.show()

# %% [markdown]
# 1) Calcular el histograma de la imagen original
# 2) Calcular la cdf (cumulative distribution function)
# 3) Remapear los valores de la imagen original a los de la cdf

# %%
ardilla_gray_eq = cv.equalizeHist(ardilla_gray)

# %%
plt.imshow(np.hstack((ardilla_gray, ardilla_gray_eq)), cmap="gray")
plt.show()

# %%
hist_gray_eq = cv.calcHist([ardilla_gray_eq], [0], None, [256], [0, 256])
plt.plot(hist_gray_eq)
plt.show()

# %%
print(ardilla_gray.size)
# Out:
# 227910

# %%
print(ardilla_gray_eq.size)
# Out:
# 227910

# %% [markdown]
# ---
# COLOR
#
# RGB

# %%
ardilla_rgb = cv.imread("/Users/miguelcamargorojas/Documents/UP/PDI-Ago-dic25/Grupo B/images/squirrel_cls.jpg")[:, :, ::-1]

# %%
r, g, b = cv.split(ardilla_rgb)

# %%
r_eq = cv.equalizeHist(r)

# %%
plt.imshow(ardilla_rgb)
plt.show()

# %%
plt.imshow(cv.merge((r_eq, g, b)))
plt.show()

# %% [markdown]
# ---
# 24 de septiembre
# Para 1 pt. sobre la calif. del examen del 2º Parcial
#
# Presentación (10 - 15 mins):
# * Qué es?
# * Para qué sirve?
# * Cómo convierto desde y hacia ese espacio de color?
#
# 1) Grayscale => Elva
# 2) RGB/BGR => Emiliano Santín
# 3) CMY / CMYK => Mauricio
# 4) YCbCr => Andrés
# 5) HSV => Esteban Montes
